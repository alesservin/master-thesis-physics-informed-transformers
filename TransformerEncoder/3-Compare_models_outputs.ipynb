# %%
# # In case the Int Slider does not appear, run:
# !pip install ipywidgets
# !jupyter lab clean
# # restart kernel

# %%
import pandas as pd
import ipywidgets as widgets
from IPython.display import display
import os
import plotly.graph_objects as go
import plotly.colors as pc

# %%
# !pip list --not-required

# %%
# Define column names for plot
columns_to_keep = ["Time [s]", "SoC [%]", "Physics-and-Transformer", "Physics", "Transformer"]    # All models results
# columns_to_keep = ["Time [s]", "SoC [%]", "Transformer"]    # Only Transformer results
# columns_to_keep = ["Time [s]", "SoC [%]", "Physics-and-Transformer", "Physics"]    # Physics and Transformers-And-Physics

# %% [markdown]
# # Define results for which dataset to display

# %%
# 1. Dataset: Full trips
dataset = "results/"

# %% [markdown]
# # List all experiment folders

# %%
def list_directories(path):
    directories = [f"{path}/{d}" for d in os.listdir(path) if os.path.isdir(os.path.join(path, d)) 
                   and ".ipynb_checkpoints" not in d]
    return directories

# %%
experiments_paths = list_directories(dataset)
experiments_paths
# Out:
# ['results//1-Delta approach, Lr=1e-05, epochs=200, dropout=0.1',
#  'results//10-Data Loss + Physics Loss, lambda=0.5, Lr=0.0001, epochs=100, dropout=0.25',
#  'results//11-Data Loss + Physics Loss, lambda=0.5, Lr=0.0001, epochs=100, dropout=0.1',
#  'results//2-Delta approach, Lr=1e-05, epochs=100, dropout=0.2',
#  'results//3-Delta approach, Lr=1e-05, epochs=100, dropout=0.1',
#  'results//4-Delta approach, Lr=0.001, epochs=100, dropout=0.2',
#  'results//5-Delta approach, Lr=0.001, epochs=100, dropout=0.1',
#  'results//6-Delta approach, Lr=0.0001, epochs=100, dropout=0.2',
#  'results//7-Delta approach, Lr=0.0001, epochs=100, dropout=0.1',
#  'results//8-Data Loss + Physics Loss, lambda=10, Lr=0.0001, epochs=100, dropout=0.25',
#  'results//9-Data Loss + Physics Loss, lambda=10, Lr=0.0001, epochs=100, dropout=0.1']

# %% [markdown]
# # Unify results of all models in each experiment

# %%
def get_filepaths_with_extension(file_extension=".csv", directory="."):
    output = []
    
    for file in os.listdir(directory):  
        # Check if the file has the required extension
        if file.endswith(file_extension):
            output.append(f"{directory}/{file}") 
            
    return output

# %% [markdown]
# ## List all files from first model found

# %%
first_model_path = list_directories(experiments_paths[0])[0]
first_model_path += "/test_data_and_model_output"
first_model_path
# Out:
# 'results//1-Delta approach, Lr=1e-05, epochs=200, dropout=0.1/Physics/test_data_and_model_output'

# %%
first_model_output_filenames = get_filepaths_with_extension(file_extension=".csv", directory=first_model_path)
first_model_output_filenames = [path.split("/")[-1] for path in first_model_output_filenames]    # keep only filename
first_model_output_filenames
# Out:
# ['file-0.csv',
#  'file-1.csv',
#  'file-2.csv',
#  'file-3.csv',
#  'file-4.csv',
#  'file-5.csv',
#  'file-6.csv',
#  'file-7.csv',
#  'file-8.csv',
#  'file-9.csv']

# %% [markdown]
# ## Get and Concatenate results of all models of each experiment

# %%
dict_experiments_results = {}

# %%
for experiment_path in experiments_paths:
    # print(experiment_path)
    # get all model directories
    models_directories = list_directories(experiment_path)

    models_output_directories = [f"{model}/test_data_and_model_output" for model in models_directories]    # add directory where models store their output
    
    # get results from each model
    experiment_result = []
    for output_filename in first_model_output_filenames:    # iterate over each filename to make sure the comparison of the different models is correct
        df = None
        for models_output_directory in models_output_directories:    # iterate over the output directories of each model
            csv_filepath = f"{models_output_directory}/{output_filename}"
            df_new = pd.read_csv(csv_filepath, sep=";", encoding="ISO-8859-2")

            # if there is no dataframe stored yet
            if df is None:
                df = df_new.copy()
            else: 
                df = pd.concat([df, df_new], axis=1)    # concatenating along columns 

        # keep only important columns for plots
        df = df[columns_to_keep]    
        # remove duplicated columns
        df = df.loc[:,~df.columns.duplicated()]
        
        # print(df)
        experiment_result.append(df)

    experiment_name = experiment_path.split("/")[-1]
    dict_experiments_results[experiment_name] = experiment_result

# %%
dict_experiments_results
# Out:
# {'1-Delta approach, Lr=1e-05, epochs=200, dropout=0.1': [          Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     85.4                85.531641  85.400002
#   1         0.099959     85.4                85.531566  85.399825
#   2         0.199934     85.4                85.530805  85.399643
#   3         0.300032     85.4                85.528599  85.399452
#   4         0.400008     85.4                85.527251  85.399246
#   ...            ...      ...                      ...        ...
#   13620  1362.000000     71.5                71.481405  68.958252
#   13621  1362.100000     71.5                71.488701  68.957993
#   13622  1362.200000     71.5                71.496001  68.957733
#   13623  1362.300000     71.5                71.488346  68.957466
#   13624  1362.400000     71.5                71.480699  68.957199
#
#   [13625 rows x 4 columns],
#           Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017     84.2                84.466001  84.199997
#   1       0.099959     84.2                84.465918  84.199799
#   2       0.199934     84.2                84.462916  84.199570
#   3       0.300032     84.2                84.458030  84.199302
#   4       0.400008     84.2                84.459546  84.199027
#   ...          ...      ...                      ...        ...
#   9202  920.200000     70.4                70.607408  67.957092
#   9203  920.300000     70.4                70.608245  67.957046
#   9204  920.400000     70.4                70.608497  67.957008
#   9205  920.500000     70.4                70.607872  67.956970
#   9206  920.600000     70.4                70.607531  67.956924
#
#   [9207 rows x 4 columns],
#           Time [s]    SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017  52.600002                52.583707  52.599998
#   1       0.099959  52.600002                52.585095  52.599686
#   2       0.199934  52.600002                52.592581  52.599388
#   3       0.300032  52.600002                52.597050  52.599086
#   4       0.400008  52.600002                52.590736  52.598751
#   ...          ...        ...                      ...        ...
#   7951  795.100000  38.100000                36.876504  35.464402
#   7952  795.200000  38.100000                36.876584  35.464357
#   7953  795.300000  38.100000                36.876796  35.464308
#   7954  795.399960  38.100000                36.877544  35.464264
#   7955  795.500000  38.100000                36.878156  35.464219
#
#   [7956 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     83.8                83.889044  83.800002
#   1         0.099959     83.8                83.888444  83.799309
#   2         0.199934     83.8                83.887833  83.798606
#   3         0.300032     83.8                83.887231  83.797913
#   4         0.400008     83.8                83.887129  83.797210
#   ...            ...      ...                      ...        ...
#   14167  1416.700000     68.0                67.914357  65.026192
#   14168  1416.800000     68.0                67.913728  65.025826
#   14169  1416.900000     68.0                67.921272  65.025482
#   14170  1417.000000     68.0                67.931156  65.025177
#   14171  1417.100000     68.0                67.933382  65.024879
#
#   [14172 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     72.1                72.057417  72.099999
#   1         0.099959     72.1                72.057210  72.099709
#   2         0.199934     72.1                72.056192  72.099403
#   3         0.300032     72.1                72.054626  72.099075
#   4         0.400008     72.1                72.055179  72.098739
#   ...            ...      ...                      ...        ...
#   28516  2851.599900     44.5                44.627162  39.441486
#   28517  2851.700000     44.5                44.631589  39.441329
#   28518  2851.800000     44.5                44.633255  39.441178
#   28519  2851.900000     44.5                44.619427  39.441015
#   28520  2852.000000     44.5                44.607770  39.440841
#
#   [28521 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     72.1                72.171316  72.099999
#   1         0.099959     72.1                72.168047  72.099861
#   2         0.199934     72.1                72.164574  72.099686
#   3         0.300032     72.1                72.163433  72.099502
#   4         0.400008     72.1                72.162201  72.099297
#   ...            ...      ...                      ...        ...
#   10963  1096.300000     57.8                57.769479  55.191467
#   10964  1096.400000     57.8                57.767626  55.191215
#   10965  1096.500000     57.8                57.768197  55.190971
#   10966  1096.600000     57.8                57.770683  55.190734
#   10967  1096.700000     57.8                57.771785  55.190499
#
#   [10968 rows x 4 columns],
#           Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017     77.4                77.391340  77.400001
#   1       0.099959     77.4                77.390857  77.399421
#   2       0.199934     77.4                77.390376  77.398842
#   3       0.300032     77.4                77.401426  77.398292
#   4       0.400008     77.4                77.412472  77.397773
#   ...          ...      ...                      ...        ...
#   5475  547.500000     71.6                71.509875  70.497490
#   5476  547.600000     71.6                71.506854  70.497284
#   5477  547.700000     71.6                71.505183  70.497063
#   5478  547.800050     71.6                71.504272  70.496842
#   5479  547.899960     71.6                71.503940  70.496620
#
#   [5480 rows x 4 columns],
#           Time [s]    SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017  31.500000                31.315080  31.500002
#   1       0.099959  31.500000                31.314547  31.499396
#   2       0.199934  31.500000                31.312580  31.498767
#   3       0.300032  31.500000                31.310029  31.498099
#   4       0.400008  31.500000                31.309631  31.497425
#   ...          ...        ...                      ...        ...
#   9680  968.000000  15.400002                15.398490  12.416431
#   9681  968.100000  15.400002                15.401997  12.416174
#   9682  968.200000  15.400002                15.402732  12.415924
#   9683  968.300000  15.400002                15.397158  12.415648
#   9684  968.400000  15.400002                15.393317  12.415353
#
#   [9685 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     65.0                65.198176  65.000000
#   1         0.099959     65.0                65.197252  64.999153
#   2         0.199934     65.0                65.195198  64.998291
#   3         0.300032     65.0                65.194887  64.997429
#   4         0.400008     65.0                65.198976  64.996582
#   ...            ...      ...                      ...        ...
#   16424  1642.400000     48.8                48.432105  45.762414
#   16425  1642.500000     48.8                48.421608  45.762187
#   16426  1642.600000     48.8                48.430885  45.761971
#   16427  1642.700000     48.8                48.440195  45.761764
#   16428  1642.799900     48.8                48.440108  45.761558
#
#   [16429 rows x 4 columns],
#           Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017     73.9                74.014023  73.900001
#   1       0.099959     73.9                74.013829  73.899711
#   2       0.199934     73.9                74.012711  73.899399
#   3       0.300032     73.9                74.010361  73.899048
#   4       0.400008     73.9                74.010820  73.898682
#   ...          ...      ...                      ...        ...
#   2926  292.599950     71.3                71.429799  70.780327
#   2927  292.699980     71.3                71.418053  70.779450
#   2928  292.800020     71.3                71.413719  70.778534
#   2929  292.900000     71.3                71.419286  70.777626
#   2930  292.999970     71.3                71.422370  70.776726
#
#   [2931 rows x 4 columns]],
#  '10-Data Loss + Physics Loss, lambda=0.5, Lr=0.0001, epochs=100, dropout=0.25': [          Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     85.4                85.424086  85.400002
#   1         0.099959     85.4                85.423743  85.399825
#   2         0.199934     85.4                85.425723  85.399643
#   3         0.300032     85.4                85.432617  85.399452
#   4         0.400008     85.4                85.436069  85.399246
#   ...            ...      ...                      ...        ...
#   13620  1362.000000     71.5                71.226700  68.958252
#   13621  1362.100000     71.5                71.182609  68.957993
#   13622  1362.200000     71.5                71.138602  68.957733
#   13623  1362.300000     71.5                71.181663  68.957466
#   13624  1362.400000     71.5                71.224800  68.957199
#
#   [13625 rows x 4 columns],
#           Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017     84.2                84.384008  84.199997
#   1       0.099959     84.2                84.383494  84.199799
#   2       0.199934     84.2                84.398519  84.199570
#   3       0.300032     84.2                84.421358  84.199302
#   4       0.400008     84.2                84.416179  84.199027
#   ...          ...      ...                      ...        ...
#   9202  920.200000     70.4                68.771520  67.957092
#   9203  920.300000     70.4                68.766432  67.957046
#   9204  920.400000     70.4                68.764543  67.957008
#   9205  920.500000     70.4                68.767451  67.956970
#   9206  920.600000     70.4                68.768755  67.956924
#
#   [9207 rows x 4 columns],
#           Time [s]    SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017  52.600002                51.711589  52.599998
#   1       0.099959  52.600002                51.700805  52.599686
#   2       0.199934  52.600002                51.652334  52.599388
#   3       0.300032  52.600002                51.621764  52.599086
#   4       0.400008  52.600002                51.654750  52.598751
#   ...          ...        ...                      ...        ...
#   7951  795.100000  38.100000                41.215870  35.464402
#   7952  795.200000  38.100000                41.215202  35.464357
#   7953  795.300000  38.100000                41.213717  35.464308
#   7954  795.399960  38.100000                41.208999  35.464264
#   7955  795.500000  38.100000                41.205075  35.464219
#
#   [7956 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     83.8                84.066259  83.800002
#   1         0.099959     83.8                84.065821  83.799309
#   2         0.199934     83.8                84.065381  83.798606
#   3         0.300032     83.8                84.064941  83.797913
#   4         0.400008     83.8                84.061657  83.797210
#   ...            ...      ...                      ...        ...
#   14167  1416.700000     68.0                67.189810  65.026192
#   14168  1416.800000     68.0                67.191689  65.025826
#   14169  1416.900000     68.0                67.151075  65.025482
#   14170  1417.000000     68.0                67.098116  65.025177
#   14171  1417.100000     68.0                67.085692  65.024879
#
#   [14172 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     72.1                72.142734  72.099999
#   1         0.099959     72.1                72.141958  72.099709
#   2         0.199934     72.1                72.144502  72.099403
#   3         0.300032     72.1                72.149469  72.099075
#   4         0.400008     72.1                72.142931  72.098739
#   ...            ...      ...                      ...        ...
#   28516  2851.599900     44.5                43.435006  39.441486
#   28517  2851.700000     44.5                43.400645  39.441329
#   28518  2851.800000     44.5                43.385848  39.441178
#   28519  2851.900000     44.5                43.482598  39.441015
#   28520  2852.000000     44.5                43.562248  39.440841
#
#   [28521 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     72.1                71.508375  72.099999
#   1         0.099959     72.1                71.523199  72.099861
#   2         0.199934     72.1                71.538466  72.099686
#   3         0.300032     72.1                71.541061  72.099502
#   4         0.400008     72.1                71.543404  72.099297
#   ...            ...      ...                      ...        ...
#   10963  1096.300000     57.8                56.191717  55.191467
#   10964  1096.400000     57.8                56.197965  55.191215
#   10965  1096.500000     57.8                56.194464  55.190971
#   10966  1096.600000     57.8                56.183287  55.190734
#   10967  1096.700000     57.8                56.177689  55.190499
#
#   [10968 rows x 4 columns],
#           Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017     77.4                77.541910  77.400001
#   1       0.099959     77.4                77.541161  77.399421
#   2       0.199934     77.4                77.540416  77.398842
#   3       0.300032     77.4                77.452079  77.398292
#   4       0.400008     77.4                77.365265  77.397773
#   ...          ...      ...                      ...        ...
#   5475  547.500000     71.6                70.733526  70.497490
#   5476  547.600000     71.6                70.753334  70.497284
#   5477  547.700000     71.6                70.763753  70.497063
#   5478  547.800050     71.6                70.768922  70.496842
#   5479  547.899960     71.6                70.770007  70.496620
#
#   [5480 rows x 4 columns],
#           Time [s]    SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017  31.500000                34.055954  31.500002
#   1       0.099959  31.500000                34.055534  31.499396
#   2       0.199934  31.500000                34.065074  31.498767
#   3       0.300032  31.500000                34.078787  31.498099
#   4       0.400008  31.500000                34.078248  31.497425
#   ...          ...        ...                      ...        ...
#   9680  968.000000  15.400002                27.637751  12.416431
#   9681  968.100000  15.400002                27.637189  12.416174
#   9682  968.200000  15.400002                27.637064  12.415924
#   9683  968.300000  15.400002                27.637911  12.415648
#   9684  968.400000  15.400002                27.638498  12.415353
#
#   [9685 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     65.0                63.251948  65.000000
#   1         0.099959     65.0                63.252031  64.999153
#   2         0.199934     65.0                63.259834  64.998291
#   3         0.300032     65.0                63.256146  64.997429
#   4         0.400008     65.0                63.223607  64.996582
#   ...            ...      ...                      ...        ...
#   16424  1642.400000     48.8                46.066585  45.762414
#   16425  1642.500000     48.8                46.116903  45.762187
#   16426  1642.600000     48.8                46.070442  45.761971
#   16427  1642.700000     48.8                46.023795  45.761764
#   16428  1642.799900     48.8                46.023301  45.761558
#
#   [16429 rows x 4 columns],
#           Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017     73.9                72.712607  73.900001
#   1       0.099959     73.9                72.711911  73.899711
#   2       0.199934     73.9                72.717846  73.899399
#   3       0.300032     73.9                72.730854  73.899048
#   4       0.400008     73.9                72.724902  73.898682
#   ...          ...      ...                      ...        ...
#   2926  292.599950     71.3                69.352136  70.780327
#   2927  292.699980     71.3                69.399751  70.779450
#   2928  292.800020     71.3                69.411535  70.778534
#   2929  292.900000     71.3                69.375679  70.777626
#   2930  292.999970     71.3                69.354007  70.776726
#
#   [2931 rows x 4 columns]],
#  '11-Data Loss + Physics Loss, lambda=0.5, Lr=0.0001, epochs=100, dropout=0.1': [          Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     85.4                85.740911  85.400002
#   1         0.099959     85.4                85.740457  85.399825
#   2         0.199934     85.4                85.745490  85.399643
#   3         0.300032     85.4                85.762185  85.399452
#   4         0.400008     85.4                85.772405  85.399246
#   ...            ...      ...                      ...        ...
#   13620  1362.000000     71.5                70.318004  68.958252
#   13621  1362.100000     71.5                70.273500  68.957993
#   13622  1362.200000     71.5                70.228881  68.957733
#   13623  1362.300000     71.5                70.272479  68.957466
#   13624  1362.400000     71.5                70.315965  68.957199
#
#   [13625 rows x 4 columns],
#           Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017     84.2                83.323728  84.199997
#   1       0.099959     84.2                83.323181  84.199799
#   2       0.199934     84.2                83.346773  84.199570
#   3       0.300032     84.2                83.382159  84.199302
#   4       0.400008     84.2                83.368134  84.199027
#   ...          ...      ...                      ...        ...
#   9202  920.200000     70.4                68.914802  67.957092
#   9203  920.300000     70.4                68.908933  67.957046
#   9204  920.400000     70.4                68.907096  67.957008
#   9205  920.500000     70.4                68.911333  67.956970
#   9206  920.600000     70.4                68.913552  67.956924
#
#   [9207 rows x 4 columns],
#           Time [s]    SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017  52.600002                53.061898  52.599998
#   1       0.099959  52.600002                53.045610  52.599686
#   2       0.199934  52.600002                52.971868  52.599388
#   3       0.300032  52.600002                52.928823  52.599086
#   4       0.400008  52.600002                52.993564  52.598751
#   ...          ...        ...                      ...        ...
#   7951  795.100000  38.100000                40.629170  35.464402
#   7952  795.200000  38.100000                40.628593  35.464357
#   7953  795.300000  38.100000                40.627086  35.464308
#   7954  795.399960  38.100000                40.621825  35.464264
#   7955  795.500000  38.100000                40.617509  35.464219
#
#   [7956 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     83.8                84.423813  83.800002
#   1         0.099959     83.8                84.423314  83.799309
#   2         0.199934     83.8                84.422810  83.798606
#   3         0.300032     83.8                84.422306  83.797913
#   4         0.400008     83.8                84.417518  83.797210
#   ...            ...      ...                      ...        ...
#   14167  1416.700000     68.0                66.597457  65.026192
#   14168  1416.800000     68.0                66.602521  65.025826
#   14169  1416.900000     68.0                66.557708  65.025482
#   14170  1417.000000     68.0                66.497371  65.025177
#   14171  1417.100000     68.0                66.482986  65.024879
#
#   [14172 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     72.1                72.458909  72.099999
#   1         0.099959     72.1                72.458171  72.099709
#   2         0.199934     72.1                72.463458  72.099403
#   3         0.300032     72.1                72.472838  72.099075
#   4         0.400008     72.1                72.461417  72.098739
#   ...            ...      ...                      ...        ...
#   28516  2851.599900     44.5                45.920332  39.441486
#   28517  2851.700000     44.5                45.885862  39.441329
#   28518  2851.800000     44.5                45.870533  39.441178
#   28519  2851.900000     44.5                45.966541  39.441015
#   28520  2852.000000     44.5                46.046414  39.440841
#
#   [28521 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     72.1                70.859796  72.099999
#   1         0.099959     72.1                70.878365  72.099861
#   2         0.199934     72.1                70.899495  72.099686
#   3         0.300032     72.1                70.903473  72.099502
#   4         0.400008     72.1                70.907639  72.099297
#   ...            ...      ...                      ...        ...
#   10963  1096.300000     57.8                57.711958  55.191467
#   10964  1096.400000     57.8                57.719668  55.191215
#   10965  1096.500000     57.8                57.715867  55.190971
#   10966  1096.600000     57.8                57.703003  55.190734
#   10967  1096.700000     57.8                57.696736  55.190499
#
#   [10968 rows x 4 columns],
#           Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017     77.4                77.768115  77.400001
#   1       0.099959     77.4                77.767399  77.399421
#   2       0.199934     77.4                77.766701  77.398842
#   3       0.300032     77.4                77.653345  77.398292
#   4       0.400008     77.4                77.539128  77.397773
#   ...          ...      ...                      ...        ...
#   5475  547.500000     71.6                70.104852  70.497490
#   5476  547.600000     71.6                70.130110  70.497284
#   5477  547.700000     71.6                70.143584  70.497063
#   5478  547.800050     71.6                70.150370  70.496842
#   5479  547.899960     71.6                70.151963  70.496620
#
#   [5480 rows x 4 columns],
#           Time [s]    SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017  31.500000                34.766619  31.500002
#   1       0.099959  31.500000                34.766294  31.499396
#   2       0.199934  31.500000                34.780000  31.498767
#   3       0.300032  31.500000                34.800843  31.498099
#   4       0.400008  31.500000                34.801414  31.497425
#   ...          ...        ...                      ...        ...
#   9680  968.000000  15.400002                26.954123  12.416431
#   9681  968.100000  15.400002                26.950452  12.416174
#   9682  968.200000  15.400002                26.949550  12.415924
#   9683  968.300000  15.400002                26.954980  12.415648
#   9684  968.400000  15.400002                26.958638  12.415353
#
#   [9685 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     65.0                64.519048  65.000000
#   1         0.099959     65.0                64.520313  64.999153
#   2         0.199934     65.0                64.532303  64.998291
#   3         0.300032     65.0                64.528966  64.997429
#   4         0.400008     65.0                64.487234  64.996582
#   ...            ...      ...                      ...        ...
#   16424  1642.400000     48.8                50.020167  45.762414
#   16425  1642.500000     48.8                50.076884  45.762187
#   16426  1642.600000     48.8                50.025710  45.761971
#   16427  1642.700000     48.8                49.974513  45.761764
#   16428  1642.799900     48.8                49.974142  45.761558
#
#   [16429 rows x 4 columns],
#           Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017     73.9                72.476768  73.900001
#   1       0.099959     73.9                72.476086  73.899711
#   2       0.199934     73.9                72.484580  73.899399
#   3       0.300032     73.9                72.503043  73.899048
#   4       0.400008     73.9                72.493419  73.898682
#   ...          ...      ...                      ...        ...
#   2926  292.599950     71.3                68.784563  70.780327
#   2927  292.699980     71.3                68.862584  70.779450
#   2928  292.800020     71.3                68.887789  70.778534
#   2929  292.900000     71.3                68.840448  70.777626
#   2930  292.999970     71.3                68.812074  70.776726
#
#   [2931 rows x 4 columns]],
#  '2-Delta approach, Lr=1e-05, epochs=100, dropout=0.2': [          Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     85.4                85.596107  85.400002
#   1         0.099959     85.4                85.596021  85.399825
#   2         0.199934     85.4                85.595306  85.399643
#   3         0.300032     85.4                85.593214  85.399452
#   4         0.400008     85.4                85.591877  85.399246
#   ...            ...      ...                      ...        ...
#   13620  1362.000000     71.5                71.406525  68.958252
#   13621  1362.100000     71.5                71.413903  68.957993
#   13622  1362.200000     71.5                71.421282  68.957733
#   13623  1362.300000     71.5                71.413578  68.957466
#   13624  1362.400000     71.5                71.405874  68.957199
#
#   [13625 rows x 4 columns],
#           Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017     84.2                84.570610  84.199997
#   1       0.099959     84.2                84.570516  84.199799
#   2       0.199934     84.2                84.566896  84.199570
#   3       0.300032     84.2                84.561760  84.199302
#   4       0.400008     84.2                84.563144  84.199027
#   ...          ...      ...                      ...        ...
#   9202  920.200000     70.4                70.446289  67.957092
#   9203  920.300000     70.4                70.447088  67.957046
#   9204  920.400000     70.4                70.447329  67.957008
#   9205  920.500000     70.4                70.446706  67.956970
#   9206  920.600000     70.4                70.446370  67.956924
#
#   [9207 rows x 4 columns],
#           Time [s]    SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017  52.600002                52.580050  52.599998
#   1       0.099959  52.600002                52.581491  52.599686
#   2       0.199934  52.600002                52.589223  52.599388
#   3       0.300032  52.600002                52.593533  52.599086
#   4       0.400008  52.600002                52.586094  52.598751
#   ...          ...        ...                      ...        ...
#   7951  795.100000  38.100000                36.881763  35.464402
#   7952  795.200000  38.100000                36.881812  35.464357
#   7953  795.300000  38.100000                36.882036  35.464308
#   7954  795.399960  38.100000                36.882964  35.464264
#   7955  795.500000  38.100000                36.883718  35.464219
#
#   [7956 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     83.8                83.993349  83.800002
#   1         0.099959     83.8                83.992744  83.799309
#   2         0.199934     83.8                83.992131  83.798606
#   3         0.300032     83.8                83.991526  83.797913
#   4         0.400008     83.8                83.991446  83.797210
#   ...            ...      ...                      ...        ...
#   14167  1416.700000     68.0                67.840163  65.026192
#   14168  1416.800000     68.0                67.839036  65.025826
#   14169  1416.900000     68.0                67.847862  65.025482
#   14170  1417.000000     68.0                67.859560  65.025177
#   14171  1417.100000     68.0                67.862040  65.024879
#
#   [14172 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     72.1                72.169406  72.099999
#   1         0.099959     72.1                72.169188  72.099709
#   2         0.199934     72.1                72.167886  72.099403
#   3         0.300032     72.1                72.165882  72.099075
#   4         0.400008     72.1                72.166240  72.098739
#   ...            ...      ...                      ...        ...
#   28516  2851.599900     44.5                44.850201  39.441486
#   28517  2851.700000     44.5                44.854860  39.441329
#   28518  2851.800000     44.5                44.856489  39.441178
#   28519  2851.900000     44.5                44.841364  39.441015
#   28520  2852.000000     44.5                44.828758  39.440841
#
#   [28521 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     72.1                72.319126  72.099999
#   1         0.099959     72.1                72.315476  72.099861
#   2         0.199934     72.1                72.311556  72.099686
#   3         0.300032     72.1                72.309975  72.099502
#   4         0.400008     72.1                72.308386  72.099297
#   ...            ...      ...                      ...        ...
#   10963  1096.300000     57.8                57.671200  55.191467
#   10964  1096.400000     57.8                57.669074  55.191215
#   10965  1096.500000     57.8                57.669732  55.190971
#   10966  1096.600000     57.8                57.672559  55.190734
#   10967  1096.700000     57.8                57.673808  55.190499
#
#   [10968 rows x 4 columns],
#           Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017     77.4                77.440068  77.400001
#   1       0.099959     77.4                77.439574  77.399421
#   2       0.199934     77.4                77.439083  77.398842
#   3       0.300032     77.4                77.450240  77.398292
#   4       0.400008     77.4                77.461452  77.397773
#   ...          ...      ...                      ...        ...
#   5475  547.500000     71.6                71.472889  70.497490
#   5476  547.600000     71.6                71.470217  70.497284
#   5477  547.700000     71.6                71.468705  70.497063
#   5478  547.800050     71.6                71.467849  70.496842
#   5479  547.899960     71.6                71.467512  70.496620
#
#   [5480 rows x 4 columns],
#           Time [s]    SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017  31.500000                31.389857  31.500002
#   1       0.099959  31.500000                31.389289  31.499396
#   2       0.199934  31.500000                31.386959  31.498767
#   3       0.300032  31.500000                31.383709  31.498099
#   4       0.400008  31.500000                31.383166  31.497425
#   ...          ...        ...                      ...        ...
#   9680  968.000000  15.400002                15.572203  12.416431
#   9681  968.100000  15.400002                15.576118  12.416174
#   9682  968.200000  15.400002                15.576930  12.415924
#   9683  968.300000  15.400002                15.570701  12.415648
#   9684  968.400000  15.400002                15.566488  12.415353
#
#   [9685 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     65.0                65.270264  65.000000
#   1         0.099959     65.0                65.269266  64.999153
#   2         0.199934     65.0                65.266922  64.998291
#   3         0.300032     65.0                65.266574  64.997429
#   4         0.400008     65.0                65.271236  64.996582
#   ...            ...      ...                      ...        ...
#   16424  1642.400000     48.8                48.337784  45.762414
#   16425  1642.500000     48.8                48.326751  45.762187
#   16426  1642.600000     48.8                48.336561  45.761971
#   16427  1642.700000     48.8                48.346352  45.761764
#   16428  1642.799900     48.8                48.346275  45.761558
#
#   [16429 rows x 4 columns],
#           Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017     73.9                74.092355  73.900001
#   1       0.099959     73.9                74.092150  73.899711
#   2       0.199934     73.9                74.090945  73.899399
#   3       0.300032     73.9                74.088636  73.899048
#   4       0.400008     73.9                74.089367  73.898682
#   ...          ...      ...                      ...        ...
#   2926  292.599950     71.3                71.489737  70.780327
#   2927  292.699980     71.3                71.476500  70.779450
#   2928  292.800020     71.3                71.471337  70.778534
#   2929  292.900000     71.3                71.477455  70.777626
#   2930  292.999970     71.3                71.480755  70.776726
#
#   [2931 rows x 4 columns]],
#  '3-Delta approach, Lr=1e-05, epochs=100, dropout=0.1': [          Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     85.4                85.461916  85.400002
#   1         0.099959     85.4                85.461836  85.399825
#   2         0.199934     85.4                85.461074  85.399643
#   3         0.300032     85.4                85.458855  85.399452
#   4         0.400008     85.4                85.457533  85.399246
#   ...            ...      ...                      ...        ...
#   13620  1362.000000     71.5                71.353998  68.958252
#   13621  1362.100000     71.5                71.361498  68.957993
#   13622  1362.200000     71.5                71.369003  68.957733
#   13623  1362.300000     71.5                71.361142  68.957466
#   13624  1362.400000     71.5                71.353287  68.957199
#
#   [13625 rows x 4 columns],
#           Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017     84.2                84.445055  84.199997
#   1       0.099959     84.2                84.444964  84.199799
#   2       0.199934     84.2                84.441384  84.199570
#   3       0.300032     84.2                84.435966  84.199302
#   4       0.400008     84.2                84.437477  84.199027
#   ...          ...      ...                      ...        ...
#   9202  920.200000     70.4                70.477192  67.957092
#   9203  920.300000     70.4                70.478048  67.957046
#   9204  920.400000     70.4                70.478301  67.957008
#   9205  920.500000     70.4                70.477634  67.956970
#   9206  920.600000     70.4                70.477269  67.956924
#
#   [9207 rows x 4 columns],
#           Time [s]    SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017  52.600002                52.580985  52.599998
#   1       0.099959  52.600002                52.582585  52.599686
#   2       0.199934  52.600002                52.591197  52.599388
#   3       0.300032  52.600002                52.596137  52.599086
#   4       0.400008  52.600002                52.587986  52.598751
#   ...          ...        ...                      ...        ...
#   7951  795.100000  38.100000                36.894532  35.464402
#   7952  795.200000  38.100000                36.894603  35.464357
#   7953  795.300000  38.100000                36.894818  35.464308
#   7954  795.399960  38.100000                36.895617  35.464264
#   7955  795.500000  38.100000                36.896268  35.464219
#
#   [7956 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     83.8                83.838930  83.800002
#   1         0.099959     83.8                83.838327  83.799309
#   2         0.199934     83.8                83.837714  83.798606
#   3         0.300032     83.8                83.837110  83.797913
#   4         0.400008     83.8                83.837102  83.797210
#   ...            ...      ...                      ...        ...
#   14167  1416.700000     68.0                67.805667  65.026192
#   14168  1416.800000     68.0                67.805177  65.025826
#   14169  1416.900000     68.0                67.813257  65.025482
#   14170  1417.000000     68.0                67.824204  65.025177
#   14171  1417.100000     68.0                67.826572  65.024879
#
#   [14172 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     72.1                72.058550  72.099999
#   1         0.099959     72.1                72.058334  72.099709
#   2         0.199934     72.1                72.057066  72.099403
#   3         0.300032     72.1                72.055086  72.099075
#   4         0.400008     72.1                72.055504  72.098739
#   ...            ...      ...                      ...        ...
#   28516  2851.599900     44.5                44.658809  39.441486
#   28517  2851.700000     44.5                44.663157  39.441329
#   28518  2851.800000     44.5                44.664620  39.441178
#   28519  2851.900000     44.5                44.650699  39.441015
#   28520  2852.000000     44.5                44.638867  39.440841
#
#   [28521 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     72.1                72.189247  72.099999
#   1         0.099959     72.1                72.185080  72.099861
#   2         0.199934     72.1                72.180693  72.099686
#   3         0.300032     72.1                72.179004  72.099502
#   4         0.400008     72.1                72.177268  72.099297
#   ...            ...      ...                      ...        ...
#   10963  1096.300000     57.8                57.715940  55.191467
#   10964  1096.400000     57.8                57.713808  55.191215
#   10965  1096.500000     57.8                57.714484  55.190971
#   10966  1096.600000     57.8                57.717372  55.190734
#   10967  1096.700000     57.8                57.718663  55.190499
#
#   [10968 rows x 4 columns],
#           Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017     77.4                77.341087  77.400001
#   1       0.099959     77.4                77.340601  77.399421
#   2       0.199934     77.4                77.340114  77.398842
#   3       0.300032     77.4                77.352782  77.398292
#   4       0.400008     77.4                77.365384  77.397773
#   ...          ...      ...                      ...        ...
#   5475  547.500000     71.6                71.445928  70.497490
#   5476  547.600000     71.6                71.442803  70.497284
#   5477  547.700000     71.6                71.440942  70.497063
#   5478  547.800050     71.6                71.439916  70.496842
#   5479  547.899960     71.6                71.439540  70.496620
#
#   [5480 rows x 4 columns],
#           Time [s]    SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017  31.500000                31.466419  31.500002
#   1       0.099959  31.500000                31.465877  31.499396
#   2       0.199934  31.500000                31.463695  31.498767
#   3       0.300032  31.500000                31.460598  31.498099
#   4       0.400008  31.500000                31.460142  31.497425
#   ...          ...        ...                      ...        ...
#   9680  968.000000  15.400002                15.555195  12.416431
#   9681  968.100000  15.400002                15.559113  12.416174
#   9682  968.200000  15.400002                15.559925  12.415924
#   9683  968.300000  15.400002                15.553684  12.415648
#   9684  968.400000  15.400002                15.549284  12.415353
#
#   [9685 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     65.0                65.194501  65.000000
#   1         0.099959     65.0                65.193533  64.999153
#   2         0.199934     65.0                65.191243  64.998291
#   3         0.300032     65.0                65.190956  64.997429
#   4         0.400008     65.0                65.195675  64.996582
#   ...            ...      ...                      ...        ...
#   16424  1642.400000     48.8                48.370664  45.762414
#   16425  1642.500000     48.8                48.360361  45.762187
#   16426  1642.600000     48.8                48.369441  45.761971
#   16427  1642.700000     48.8                48.378552  45.761764
#   16428  1642.799900     48.8                48.378468  45.761558
#
#   [16429 rows x 4 columns],
#           Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017     73.9                74.001944  73.900001
#   1       0.099959     73.9                74.001747  73.899711
#   2       0.199934     73.9                74.000396  73.899399
#   3       0.300032     73.9                73.997781  73.899048
#   4       0.400008     73.9                73.998328  73.898682
#   ...          ...      ...                      ...        ...
#   2926  292.599950     71.3                71.432082  70.780327
#   2927  292.699980     71.3                71.419256  70.779450
#   2928  292.800020     71.3                71.414909  70.778534
#   2929  292.900000     71.3                71.421083  70.777626
#   2930  292.999970     71.3                71.424450  70.776726
#
#   [2931 rows x 4 columns]],
#  '4-Delta approach, Lr=0.001, epochs=100, dropout=0.2': [          Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     85.4                85.368190  85.400002
#   1         0.099959     85.4                85.368080  85.399825
#   2         0.199934     85.4                85.367391  85.399643
#   3         0.300032     85.4                85.365485  85.399452
#   4         0.400008     85.4                85.364110  85.399246
#   ...            ...      ...                      ...        ...
#   13620  1362.000000     71.5                71.832799  68.958252
#   13621  1362.100000     71.5                71.837598  68.957993
#   13622  1362.200000     71.5                71.842397  68.957733
#   13623  1362.300000     71.5                71.837183  68.957466
#   13624  1362.400000     71.5                71.831968  68.957199
#
#   [13625 rows x 4 columns],
#           Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017     84.2                84.164536  84.199997
#   1       0.099959     84.2                84.164395  84.199799
#   2       0.199934     84.2                84.162277  84.199570
#   3       0.300032     84.2                84.159180  84.199302
#   4       0.400008     84.2                84.160143  84.199027
#   ...          ...      ...                      ...        ...
#   9202  920.200000     70.4                70.843573  67.957092
#   9203  920.300000     70.4                70.844394  67.957046
#   9204  920.400000     70.4                70.844629  67.957008
#   9205  920.500000     70.4                70.843970  67.956970
#   9206  920.600000     70.4                70.843602  67.956924
#
#   [9207 rows x 4 columns],
#           Time [s]    SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017  52.600002                52.463558  52.599998
#   1       0.099959  52.600002                52.464386  52.599686
#   2       0.199934  52.600002                52.469319  52.599388
#   3       0.300032  52.600002                52.472235  52.599086
#   4       0.400008  52.600002                52.467895  52.598751
#   ...          ...        ...                      ...        ...
#   7951  795.100000  38.100000                37.052576  35.464402
#   7952  795.200000  38.100000                37.052669  35.464357
#   7953  795.300000  38.100000                37.052909  35.464308
#   7954  795.399960  38.100000                37.053766  35.464264
#   7955  795.500000  38.100000                37.054469  35.464219
#
#   [7956 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     83.8                83.666988  83.800002
#   1         0.099959     83.8                83.666343  83.799309
#   2         0.199934     83.8                83.665688  83.798606
#   3         0.300032     83.8                83.665043  83.797913
#   4         0.400008     83.8                83.664745  83.797210
#   ...            ...      ...                      ...        ...
#   14167  1416.700000     68.0                68.168324  65.026192
#   14168  1416.800000     68.0                68.167833  65.025826
#   14169  1416.900000     68.0                68.173036  65.025482
#   14170  1417.000000     68.0                68.180088  65.025177
#   14171  1417.100000     68.0                68.181517  65.024879
#
#   [14172 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     72.1                71.855795  72.099999
#   1         0.099959     72.1                71.855544  72.099709
#   2         0.199934     72.1                71.855071  72.099403
#   3         0.300032     72.1                71.854442  72.099075
#   4         0.400008     72.1                71.854886  72.098739
#   ...            ...      ...                      ...        ...
#   28516  2851.599900     44.5                46.126585  39.441486
#   28517  2851.700000     44.5                46.133019  39.441329
#   28518  2851.800000     44.5                46.134552  39.441178
#   28519  2851.900000     44.5                46.110068  39.441015
#   28520  2852.000000     44.5                46.089854  39.440841
#
#   [28521 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     72.1                71.978762  72.099999
#   1         0.099959     72.1                71.977057  72.099861
#   2         0.199934     72.1                71.975161  72.099686
#   3         0.300032     72.1                71.974672  72.099502
#   4         0.400008     72.1                71.974160  72.099297
#   ...            ...      ...                      ...        ...
#   10963  1096.300000     57.8                57.986878  55.191467
#   10964  1096.400000     57.8                57.985429  55.191215
#   10965  1096.500000     57.8                57.985879  55.190971
#   10966  1096.600000     57.8                57.987822  55.190734
#   10967  1096.700000     57.8                57.988684  55.190499
#
#   [10968 rows x 4 columns],
#           Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017     77.4                77.182666  77.400001
#   1       0.099959     77.4                77.182129  77.399421
#   2       0.199934     77.4                77.181591  77.398842
#   3       0.300032     77.4                77.187389  77.398292
#   4       0.400008     77.4                77.193396  77.397773
#   ...          ...      ...                      ...        ...
#   5475  547.500000     71.6                71.287622  70.497490
#   5476  547.600000     71.6                71.280873  70.497284
#   5477  547.700000     71.6                71.277171  70.497063
#   5478  547.800050     71.6                71.275211  70.496842
#   5479  547.899960     71.6                71.274601  70.496620
#
#   [5480 rows x 4 columns],
#           Time [s]    SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017  31.500000                31.408775  31.500002
#   1       0.099959  31.500000                31.408207  31.499396
#   2       0.199934  31.500000                31.406657  31.498767
#   3       0.300032  31.500000                31.404648  31.498099
#   4       0.400008  31.500000                31.404125  31.497425
#   ...          ...        ...                      ...        ...
#   9680  968.000000  15.400002                15.265654  12.416431
#   9681  968.100000  15.400002                15.267566  12.416174
#   9682  968.200000  15.400002                15.267906  12.415924
#   9683  968.300000  15.400002                15.264652  12.415648
#   9684  968.400000  15.400002                15.262339  12.415353
#
#   [9685 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     65.0                64.978523  65.000000
#   1         0.099959     65.0                64.977931  64.999153
#   2         0.199934     65.0                64.977154  64.998291
# ...
#   ...            ...      ...                      ...        ...
#   13620  1362.000000     71.5                68.144105  68.958252
#   13621  1362.100000     71.5                68.097070  68.957993
#   13622  1362.200000     71.5                68.049816  68.957733
#   13623  1362.300000     71.5                68.096084  68.957466
#   13624  1362.400000     71.5                68.142141  68.957199
#
#   [13625 rows x 4 columns],
#           Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017     84.2                83.458655  84.199997
#   1       0.099959     84.2                83.458038  84.199799
#   2       0.199934     84.2                83.478012  84.199570
#   3       0.300032     84.2                83.508617  84.199302
#   4       0.400008     84.2                83.498687  84.199027
#   ...          ...      ...                      ...        ...
#   9202  920.200000     70.4                65.896054  67.957092
#   9203  920.300000     70.4                65.890591  67.957046
#   9204  920.400000     70.4                65.888680  67.957008
#   9205  920.500000     70.4                65.892112  67.956970
#   9206  920.600000     70.4                65.893720  67.956924
#
#   [9207 rows x 4 columns],
#           Time [s]    SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017  52.600002                53.592684  52.599998
#   1       0.099959  52.600002                53.577860  52.599686
#   2       0.199934  52.600002                53.510457  52.599388
#   3       0.300032  52.600002                53.468628  52.599086
#   4       0.400008  52.600002                53.517603  52.598751
#   ...          ...        ...                      ...        ...
#   7951  795.100000  38.100000                40.239777  35.464402
#   7952  795.200000  38.100000                40.239001  35.464357
#   7953  795.300000  38.100000                40.237441  35.464308
#   7954  795.399960  38.100000                40.232740  35.464264
#   7955  795.500000  38.100000                40.228822  35.464219
#
#   [7956 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     83.8                83.754485  83.800002
#   1         0.099959     83.8                83.753941  83.799309
#   2         0.199934     83.8                83.753399  83.798606
#   3         0.300032     83.8                83.752850  83.797913
#   4         0.400008     83.8                83.748092  83.797210
#   ...            ...      ...                      ...        ...
#   14167  1416.700000     68.0                64.278324  65.026192
#   14168  1416.800000     68.0                64.280482  65.025826
#   14169  1416.900000     68.0                64.238719  65.025482
#   14170  1417.000000     68.0                64.183190  65.025177
#   14171  1417.100000     68.0                64.170251  65.024879
#
#   [14172 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     72.1                72.160580  72.099999
#   1         0.099959     72.1                72.159777  72.099709
#   2         0.199934     72.1                72.162790  72.099403
#   3         0.300032     72.1                72.168858  72.099075
#   4         0.400008     72.1                72.160405  72.098739
#   ...            ...      ...                      ...        ...
#   28516  2851.599900     44.5                41.201050  39.441486
#   28517  2851.700000     44.5                41.163262  39.441329
#   28518  2851.800000     44.5                41.147454  39.441178
#   28519  2851.900000     44.5                41.256916  39.441015
#   28520  2852.000000     44.5                41.346497  39.440841
#
#   [28521 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     72.1                70.715732  72.099999
#   1         0.099959     72.1                70.731898  72.099861
#   2         0.199934     72.1                70.749262  72.099686
#   3         0.300032     72.1                70.751680  72.099502
#   4         0.400008     72.1                70.754067  72.099297
#   ...            ...      ...                      ...        ...
#   10963  1096.300000     57.8                56.238668  55.191467
#   10964  1096.400000     57.8                56.245172  55.191215
#   10965  1096.500000     57.8                56.241649  55.190971
#   10966  1096.600000     57.8                56.230253  55.190734
#   10967  1096.700000     57.8                56.224595  55.190499
#
#   [10968 rows x 4 columns],
#           Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017     77.4                77.132879  77.400001
#   1       0.099959     77.4                77.131991  77.399421
#   2       0.199934     77.4                77.131103  77.398842
#   3       0.300032     77.4                77.019987  77.398292
#   4       0.400008     77.4                76.908344  77.397773
#   ...          ...      ...                      ...        ...
#   5475  547.500000     71.6                69.008233  70.497490
#   5476  547.600000     71.6                69.031729  70.497284
#   5477  547.700000     71.6                69.044167  70.497063
#   5478  547.800050     71.6                69.050416  70.496842
#   5479  547.899960     71.6                69.051831  70.496620
#
#   [5480 rows x 4 columns],
#           Time [s]    SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017  31.500000                36.181574  31.500002
#   1       0.099959  31.500000                36.181012  31.499396
#   2       0.199934  31.500000                36.192870  31.498767
#   3       0.300032  31.500000                36.210789  31.498099
#   4       0.400008  31.500000                36.210253  31.497425
#   ...          ...        ...                      ...        ...
#   9680  968.000000  15.400002                27.481485  12.416431
#   9681  968.100000  15.400002                27.480567  12.416174
#   9682  968.200000  15.400002                27.480317  12.415924
#   9683  968.300000  15.400002                27.481575  12.415648
#   9684  968.400000  15.400002                27.482419  12.415353
#
#   [9685 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     65.0                64.199387  65.000000
#   1         0.099959     65.0                64.199357  64.999153
#   2         0.199934     65.0                64.206987  64.998291
#   3         0.300032     65.0                64.202776  64.997429
#   4         0.400008     65.0                64.168177  64.996582
#   ...            ...      ...                      ...        ...
#   16424  1642.400000     48.8                46.235194  45.762414
#   16425  1642.500000     48.8                46.300868  45.762187
#   16426  1642.600000     48.8                46.240237  45.761971
#   16427  1642.700000     48.8                46.179456  45.761764
#   16428  1642.799900     48.8                46.178883  45.761558
#
#   [16429 rows x 4 columns],
#           Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017     73.9                72.167790  73.900001
#   1       0.099959     73.9                72.167025  73.899711
#   2       0.199934     73.9                72.174639  73.899399
#   3       0.300032     73.9                72.190463  73.899048
#   4       0.400008     73.9                72.182032  73.898682
#   ...          ...      ...                      ...        ...
#   2926  292.599950     71.3                68.357321  70.780327
#   2927  292.699980     71.3                68.414041  70.779450
#   2928  292.800020     71.3                68.428618  70.778534
#   2929  292.900000     71.3                68.387460  70.777626
#   2930  292.999970     71.3                68.362511  70.776726
#
#   [2931 rows x 4 columns]],
#  '9-Data Loss + Physics Loss, lambda=10, Lr=0.0001, epochs=100, dropout=0.1': [          Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     85.4                85.376574  85.400002
#   1         0.099959     85.4                85.376056  85.399825
#   2         0.199934     85.4                85.380111  85.399643
#   3         0.300032     85.4                85.393948  85.399452
#   4         0.400008     85.4                85.401852  85.399246
#   ...            ...      ...                      ...        ...
#   13620  1362.000000     71.5                68.502700  68.958252
#   13621  1362.100000     71.5                68.456806  68.957993
#   13622  1362.200000     71.5                68.411507  68.957733
#   13623  1362.300000     71.5                68.455687  68.957466
#   13624  1362.400000     71.5                68.500453  68.957199
#
#   [13625 rows x 4 columns],
#           Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017     84.2                83.269951  84.199997
#   1       0.099959     84.2                83.269307  84.199799
#   2       0.199934     84.2                83.294649  84.199570
#   3       0.300032     84.2                83.333418  84.199302
#   4       0.400008     84.2                83.323765  84.199027
#   ...          ...      ...                      ...        ...
#   9202  920.200000     70.4                66.876530  67.957092
#   9203  920.300000     70.4                66.871079  67.957046
#   9204  920.400000     70.4                66.869115  67.957008
#   9205  920.500000     70.4                66.872408  67.956970
#   9206  920.600000     70.4                66.873948  67.956924
#
#   [9207 rows x 4 columns],
#           Time [s]    SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017  52.600002                53.189197  52.599998
#   1       0.099959  52.600002                53.173389  52.599686
#   2       0.199934  52.600002                53.100625  52.599388
#   3       0.300032  52.600002                53.055773  52.599086
#   4       0.400008  52.600002                53.111388  52.598751
#   ...          ...        ...                      ...        ...
#   7951  795.100000  38.100000                39.809525  35.464402
#   7952  795.200000  38.100000                39.808848  35.464357
#   7953  795.300000  38.100000                39.807291  35.464308
#   7954  795.399960  38.100000                39.802256  35.464264
#   7955  795.500000  38.100000                39.798088  35.464219
#
#   [7956 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     83.8                83.886970  83.800002
#   1         0.099959     83.8                83.886397  83.799309
#   2         0.199934     83.8                83.885824  83.798606
#   3         0.300032     83.8                83.885254  83.797913
#   4         0.400008     83.8                83.880792  83.797210
#   ...            ...      ...                      ...        ...
#   14167  1416.700000     68.0                64.594389  65.026192
#   14168  1416.800000     68.0                64.594024  65.025826
#   14169  1416.900000     68.0                64.555153  65.025482
#   14170  1417.000000     68.0                64.503630  65.025177
#   14171  1417.100000     68.0                64.491445  65.024879
#
#   [14172 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     72.1                72.341151  72.099999
#   1         0.099959     72.1                72.340312  72.099709
#   2         0.199934     72.1                72.344969  72.099403
#   3         0.300032     72.1                72.352645  72.099075
#   4         0.400008     72.1                72.342814  72.098739
#   ...            ...      ...                      ...        ...
#   28516  2851.599900     44.5                42.403469  39.441486
#   28517  2851.700000     44.5                42.369333  39.441329
#   28518  2851.800000     44.5                42.355587  39.441178
#   28519  2851.900000     44.5                42.457075  39.441015
#   28520  2852.000000     44.5                42.541542  39.440841
#
#   [28521 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     72.1                70.941845  72.099999
#   1         0.099959     72.1                70.958795  72.099861
#   2         0.199934     72.1                70.977615  72.099686
#   3         0.300032     72.1                70.980674  72.099502
#   4         0.400008     72.1                70.983771  72.099297
#   ...            ...      ...                      ...        ...
#   10963  1096.300000     57.8                56.668494  55.191467
#   10964  1096.400000     57.8                56.674989  55.191215
#   10965  1096.500000     57.8                56.671511  55.190971
#   10966  1096.600000     57.8                56.660196  55.190734
#   10967  1096.700000     57.8                56.654585  55.190499
#
#   [10968 rows x 4 columns],
#           Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017     77.4                77.311260  77.400001
#   1       0.099959     77.4                77.310471  77.399421
#   2       0.199934     77.4                77.309681  77.398842
#   3       0.300032     77.4                77.201915  77.398292
#   4       0.400008     77.4                77.094740  77.397773
#   ...          ...      ...                      ...        ...
#   5475  547.500000     71.6                69.221670  70.497490
#   5476  547.600000     71.6                69.245146  70.497284
#   5477  547.700000     71.6                69.257484  70.497063
#   5478  547.800050     71.6                69.263626  70.496842
#   5479  547.899960     71.6                69.264941  70.496620
#
#   [5480 rows x 4 columns],
#           Time [s]    SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017  31.500000                35.790523  31.500002
#   1       0.099959  31.500000                35.790093  31.499396
#   2       0.199934  31.500000                35.800917  31.498767
#   3       0.300032  31.500000                35.817531  31.498099
#   4       0.400008  31.500000                35.817024  31.497425
#   ...          ...        ...                      ...        ...
#   9680  968.000000  15.400002                27.488471  12.416431
#   9681  968.100000  15.400002                27.487046  12.416174
#   9682  968.200000  15.400002                27.486674  12.415924
#   9683  968.300000  15.400002                27.488734  12.415648
#   9684  968.400000  15.400002                27.490140  12.415353
#
#   [9685 rows x 4 columns],
#             Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0        -0.000017     65.0                64.509123  65.000000
#   1         0.099959     65.0                64.509266  64.999153
#   2         0.199934     65.0                64.517689  64.998291
#   3         0.300032     65.0                64.513303  64.997429
#   4         0.400008     65.0                64.476111  64.996582
#   ...            ...      ...                      ...        ...
#   16424  1642.400000     48.8                47.720473  45.762414
#   16425  1642.500000     48.8                47.781603  45.762187
#   16426  1642.600000     48.8                47.725672  45.761971
#   16427  1642.700000     48.8                47.670193  45.761764
#   16428  1642.799900     48.8                47.669728  45.761558
#
#   [16429 rows x 4 columns],
#           Time [s]  SoC [%]  Physics-and-Transformer    Physics
#   0      -0.000017     73.9                72.345671  73.900001
#   1       0.099959     73.9                72.344881  73.899711
#   2       0.199934     73.9                72.350939  73.899399
#   3       0.300032     73.9                72.364544  73.899048
#   4       0.400008     73.9                72.354142  73.898682
#   ...          ...      ...                      ...        ...
#   2926  292.599950     71.3                68.397089  70.780327
#   2927  292.699980     71.3                68.459423  70.779450
#   2928  292.800020     71.3                68.477663  70.778534
#   2929  292.900000     71.3                68.432505  70.777626
#   2930  292.999970     71.3                68.405328  70.776726
#
#   [2931 rows x 4 columns]]}

# %% [markdown]
# # Create interactive plots

# %%
# !pip install plotly

# %%
model_output_column_names = ["Physics-and-Transformer", "Transformer", "Physics"]

# %%
def plot_soc(file_id, model_outputs_to_display):
    
    # Use Plotly's "Safe" qualitative color palette. Source of color pallete: https://plotly.com/python/discrete-color/
    colorblind_palette = pc.qualitative.Safe

    for experiment_name in list(dict_experiments_results.keys()):
        experiment_results = dict_experiments_results[experiment_name][file_id]
    
        # Create the figure
        fig = go.Figure()
        
        # Plot actual SoC only from first model
        fig.add_trace(go.Scatter(
            x=experiment_results['Time [s]'],
            y=experiment_results['SoC [%]'],
            mode='lines',
            line=dict(width=3, color=colorblind_palette[0]),
            name='Actual SoC [%]'
        ))

        marker_styles = ['circle', 'square', 'diamond', 'cross', 'x', 'triangle-up', 'triangle-down']
        for idx_model, model_output_column_name in enumerate(model_output_column_names):
            # If model_output_column_name is not in selected model_outputs_to_display, skip
            if model_output_column_name not in model_outputs_to_display:
                continue     

            line_opacity = 0.7
            fig.add_trace(go.Scatter(
                x=experiment_results['Time [s]'],
                y=experiment_results[model_output_column_name],
                mode='lines',
                line=dict(dash='dot', width=3, 
                          color=f"rgba{tuple(map(int, colorblind_palette[(idx_model % len(colorblind_palette)) + 1][4:-1].split(',')))[:3] + (line_opacity,)}"),
                name=f"Model: {model_output_column_name}"
            ))    # color with opacity is last answer from AI assistant: https://chatgpt.com/share/67a8fb48-ae30-800b-b9c4-44caa979d630
            
        # Update layout
        fig.update_layout(
            title=f'Experiment: {experiment_name}<br><sup>Actual vs Estimated State of Charge (SoC %) of file {file_id}</sup>',
            xaxis_title='Time [s]',
            yaxis_title='State of Charge [%]',
            legend_title='Legend',
            template='plotly_white'
        )
        
        # Show the plot
        fig.show()

# %%
# get total number of files
total_files = len(dict_experiments_results[list(dict_experiments_results)[0]])    # number of dataframes in first experiments

# %%
# Create Slider for multiple selection of models
model_select_multiple = widgets.SelectMultiple(
    options=model_output_column_names,
    value=model_output_column_names,
    rows=len(model_output_column_names),
    description='Models:',
    disabled=False
)

# Create a slider for selecting the ID
id_slider = widgets.IntSlider(
    value=0, 
    min=0, 
    max=(total_files -1),    # max is the total number of file in any of the model results 
    step=1, 
    description='Test file ID:',
    continuous_update=False,
    style={'slider_button_width': '20px'}  # Enable built-in buttons
)

# Create a horizontal layout for the id_slider and model_select_multiple
controls = widgets.HBox([model_select_multiple, id_slider])

# Connect the slider to the plot function
interactive_plot = widgets.interactive_output(plot_soc, {'file_id': id_slider, 'model_outputs_to_display': model_select_multiple})

# Display the controls widgets and plot together
display(controls, interactive_plot)
# Out:
# HBox(children=(SelectMultiple(description='Models:', index=(0, 1, 2), options=('Physics-and-Transformer', 'Tra…
# Output()
